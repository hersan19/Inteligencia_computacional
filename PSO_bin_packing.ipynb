# %% [markdown]
# <a href="https://colab.research.google.com/github/hersan19/Inteligencia_computacional/blob/main/PSO_bin_packing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Se descargan los paquetes requeridos

# %%
# !pip install deap
# Out:
# Requirement already satisfied: deap in /usr/local/lib/python3.7/dist-packages (1.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deap) (1.19.5)

# %% [markdown]
# Se importan las bibliotecas que se utilizarán durante el proceso.

# %%
import math
import numpy as np
import matplotlib.path as mpath
import matplotlib.patches as mpatches
import operator
import random
import numpy
import matplotlib.pyplot as plt

from deap import base
from deap import benchmarks
from deap import creator
from deap import tools
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Se dibuja un pentágono regular que será el área factible para guardar los objetos.

# %%
def Paint(ax):        
    
    #Coordenadas de área factible
    Path = mpath.Path
    path_data = [
        (Path.MOVETO, (311.8,-16.3)),
        (Path.LINETO, (288.2,-16.3)),
        (Path.LINETO, (280.9, 6.2)),
        (Path.LINETO, (300,20.1)),
        (Path.LINETO, (319.1,6.2)),
        (Path.CLOSEPOLY, (311.8,-16.3)),
        ]
    codes, verts = zip(*path_data)
    path = mpath.Path(verts, codes)
    patch = mpatches.PathPatch(path, facecolor='r', alpha=0.5)
    ax.add_patch(patch)
    ax.axis('equal')



points =((311.8,-16.3), (288.2,-16.3), (280.9, 6.2), (300,20.1),(319.1,6.2))

# %% [markdown]
# Dibuja cada cuadrado y rectangulo valido dentro de la region factible.

# %%
def Paint_Q(List, VV, sizes, N, ax):
    Vx= VV[:N]
    Vy= VV[N:]
    for i in List:
        Paint_q(Vx[i],Vy[i],sizes[i], ax)
    

def Paint_q(vx,vy,s, ax):
    Path = mpath.Path
    #print(vx,vy)
    path_data = [
        (Path.MOVETO, (vx, vy)),
        (Path.LINETO, (vx, vy+s[1])),
        (Path.LINETO, (vx+s[0], vy+s[1])),
        (Path.LINETO, (vx+s[0], vy)),
        (Path.LINETO, (vx, vy)),
        (Path.CLOSEPOLY, (vx, vy)),
        ]
    codes, verts = zip(*path_data)
    path = mpath.Path(verts, codes)
    patch = mpatches.PathPatch(path, facecolor='b', alpha=0.5)
    ax.add_patch(patch)
    ax.axis('equal')

# %% [markdown]
# Valida que cada esquina del rectángulo o cuadrado se encuentren dentro de la region factible, con el objetivo de asegurar que toda el área este dentro de los límites establecidos en el problema.

# %% [markdown]
# Conservo aquellos que se quedan dentro del área factible

# %%
def Into(P):
    distances = [math.sqrt((x-P[0])**2+ (y-P[1])**2) for (x,y) in points]
    num = list(zip(distances, range(len(distances))))
    num.sort()
    (x,y) =(num[0][1], num[1][1])
    #print(x,y, P)
    if P[1]<-16.3 or P[1]>319.1:
        return False
      
    if (x,y)==(1,2) or (x,y)==(2,1):
        x1= -P[1]/3.08219 +871.9876/3.08219
        if P[0]<x1:
            return False
    elif (x,y)==(2,3) or (x,y)==(3,2):
        x1= (P[1]+378609/1910)* 191/139
        if P[0]<x1:
            return False
    
    elif (x,y)==(3,4) or (x,y)==(4,3):
        x1= (P[1]-455391/1910)* (-191/139)
        if P[0]>x1:
            return False
        
    elif (x,y)== (4,0) or (x,y)==(0,4):
        x1= (P[1]+713449/730)* (73/225)
        if P[0]>x1 or P[0]<-16.3:
            return False
    elif (x,y)==(0,1) or (y,x)==(1,0) and P[0]<-16.3:
        return False
         
    else:
        return True
    return True

# %% [markdown]
# Elimina las figuras que se encuentras sobrepuestas.

# %%
#Se proyectan las figuras en los ejes
#Si algunas de ellas se encuentra sobrepuesta, no se toma en cuenta

#Primero busca en las coordenadas del eje de las abcisas (x) si hay alguna intersección
def Inter(Vx, Vy, index, sizes):
    X=[(Vx[i],i) for i in index]+[(Vx[i]+sizes[i][0],i) for i in index]
    X.sort()
    L= np.array(X)[:,1]
    L_ind= set(range(len(L)))
    no_val=[]
    Total = []
    for i in range(len(L)):
        if i in L_ind and not( L[i] in no_val):
            
            l=L[i]
            j=i+1
            while  L[j]!=l:
                j+=1
            L_ind= L_ind-set([j])
           
            f= int(L[i])
            index_y= list(map(int, list(set(L[i+1:j]))))
            F = InterY(f, index_y,Vy, sizes)
            if F==[]:
                Total.append(L[i])
            else:
                no_val.extend(F)
           
    return list(map(int,Total))
            
            
            
#Se repite el proceso pero con el eje de las ordenadas (y) 
def InterY(f, index_y,Vy, sizes):
    if index_y==[]:
        return []
    index_y.append(f)
    Y = [(Vy[k],k) for k in index_y]+[(Vy[k]+sizes[k][1],k) for k in index_y]
    Y.sort()
    
    L_y= [y[1] for y in Y]
    lim1 = L_y.index(f)
    lim2=  L_y[lim1+1:].index(f)+lim1+1
    J=  L_y[lim1+1: lim2]
    if J==[] and lim1>1:
       K=[]
       for h in L_y[:lim1]:
            lim1 = L_y.index(h)
            lim2=  L_y[lim1+1:].index(h)+lim1+1
            if f in L_y[lim1+1: lim2]:
                K.append(h)
       return K
    else:
        return  L_y[lim1+1: lim2]

# %% [markdown]
# Cálculo del valor de aptitud. Área total cubierta por los rectángulos.

# %%
#Esta función de aptitud es respecto a maximizar el número de artículos dentro del área
def Fitness(VV, sizes, N):
    Vx= VV[:N]
    Vy= VV[N:]
    index= []
    for i, vx, vy in zip(range(N), Vx, Vy):
        V= [vx, vy]
        #print(V)
        if Into(V)==True:
            p = sizes[i]
            one= [V[0]+p[0], V[1]]
            second= [V[0], V[1]+p[1]]
            third=[V[0]+p[0], V[1]+p[1]]
            c=0
            
            for v in [one, second, third]:
                if Into(v)== False:
                    break
                else:
                    c+=1
            if c==3:
                index.append(i)
       
    
    F= Inter(Vx, Vy, index, sizes)
    a= Area(F, sizes)
    #print(a)
    return a, F
    
    
 #Si lo que se desea es máximizar el área total cubierta, se cambia la función anterior a esta función   
def Area(List, sizes):
   A= [sizes[i][0]*sizes[i][1] for i in List]
   return sum(A)

# %% [markdown]
# **PSO**

# %% [markdown]
# Parámetros: número de artículos, máximos y mínimos permitidos para definir las posiciones de las esquinas izquierdas inferiores de cada rectangulo.

# %%
#Un total de 50 objetos
Nitem = 50

#Una representación real
#Generan los límites de los puntos de las esquinas inferiores izquierdas
Min= [280.9]*Nitem+[-16.3]*Nitem
Max= [319.1]*Nitem+[ 20.1]*Nitem

# %% [markdown]
# Crear funciones con Deap para PSO.
# Generar caja de herramientas

# %%
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Particle", list, fitness=creator.FitnessMax, speed=list, 
    smin=None, smax=None, best=None, elements=list)

#Generamos individuos
def generate(size, pmin, pmax, smin, smax):
    #Primero se generan las partículas de forma aleatoria utilizando una distribución uniforme 
    part = creator.Particle(random.uniform(pmin[i], pmax[i]) for i in range(2*size)) 
    #Se genera la velocidad de la partícula de forma aleatoria utilizando una distribución uniforme
    part.speed = [random.uniform(smin, smax) for _ in range(2*size)]
    #La veolocidad va a estar limitada por una velocidad máxima y una velocidad mínima
    part.smin = smin
    part.smax = smax
    return part



#Se actualiza la partícula
def updateParticle(part, best, phi1, phi2):
    #Genera dos vectores aleatorios con la misma longitud que la particula
    
    u1 = list(random.uniform(0, phi1) for _ in range(len(part)))
    u2 = list(random.uniform(0, phi2) for _ in range(len(part)))
    
    #Calcular nuevos factores de aprendizaje
    #v_u1=u1*(part.best-part)  part.best mejor valor de la particula
    v_u1 = map(operator.mul, u1, map(operator.sub, part.best, part))
    #v_u2=u2*(part.best-part)  part.best mejor valor a nivel global
    v_u2 = map(operator.mul, u2, map(operator.sub, best, part))
    #v(t)= v_u1+v_u2+ v(t-1)
    part.speed = list(map(operator.add, part.speed, map(operator.add, v_u1, v_u2)))
    
    
    for i, speed in enumerate(part.speed):
        
        if abs(speed) < part.smin:
            part.speed[i] = math.copysign(part.smin, speed)
            #copia psrt.smin cambiando su signo original por el de speed
        elif abs(speed) > part.smax:
            part.speed[i] = math.copysign(part.smax, speed)
        
    #Actualizar particula
    part[:] = list(map(operator.add, part, part.speed))

toolbox = base.Toolbox()
toolbox.register("particle", generate, size=Nitem, pmin=Max, pmax=Min, smin=-1, smax=1)
toolbox.register("population", tools.initRepeat, list, toolbox.particle)
toolbox.register("update", updateParticle, phi1=2, phi2=2)
toolbox.register("evaluate", Fitness)

# %% [markdown]
# Estructura general de PSO

# %%
#Problema de maximizacion enfoque global.
def main(Pops, sizes):
    pop = toolbox.population(n=Pops)
    GEN = 500
    best = None
    
    for g in range(GEN):
        #print(g)
        for part in pop:
            apt, lis= Fitness(part, sizes, Nitem)
            part.fitness.values =(apt,)
            part.elements= lis
            
            if not part.best or part.best.fitness < part.fitness:
                part.best = creator.Particle(part)
                part.best.fitness.values = part.fitness.values
                part.best.elements = part.elements
                #Si la particula no tiene un mejor valor encontrado o si el mejor valor encontrado  es menor al  actual, entonces este es actualizado.
            if not best or best.fitness < part.fitness:
                best = creator.Particle(part)
                best.fitness.values = part.fitness.values
                best.elements = part.elements
            #Si no hay ningun vector mejor o hay un vector que tiene mejores valores que el que se considera ser mejor, entonces se actualiza.
        #print(best.fitness.values, best.elements)
        #Se actualiza a la partícula
        for part in pop:
            toolbox.update(part, best)
            
        xx,yy=Fitness(best, sizes, Nitem)
        #Generación, área, no. de objetos 
        print(g, xx, len(yy))
       
    fig, ax = plt.subplots()
    Paint(ax)
    print("="*20)
    Paint_Q( best.elements, best, sizes, Nitem,ax)
    xx,yy=Fitness(best, sizes, Nitem)
    print(g, xx, len(yy))
    plt.title("Generation: "+ str(g+1) +   "    Area: "+ str(xx), size= 20)
    plt.xticks([])
    plt.yticks([])
    plt.show()
   
    return pop, best

# %% [markdown]
# Main para ejecuta el programa con una semilla en cero.

# %%
if __name__ == "__main__":
    random.seed(0)
    print("Generaciones |  Área  | # objetos")
    PopS = 100
    sizes = [[random.randrange(1, 6),random.randrange(1,6)] for _ in range(Nitem)]

    main(PopS, sizes)
# Out:
# Generaciones |  Área  | # objetos
# 0 121 12
# 1 121 12
# 2 121 12
# 3 121 12
# 4 121 12
# 5 121 12
# 6 121 12
# 7 121 12
# 8 121 12
# 9 121 12
# 10 121 12
# 11 121 12
# 12 121 12
# 13 121 12
# 14 121 12
# 15 121 12
# 16 121 12
# 17 121 12
# 18 121 12
# 19 121 12
# 20 121 12
# 21 121 12
# 22 121 12
# 23 121 12
# 24 121 12
# 25 121 12
# 26 121 12
# 27 121 12
# 28 121 12
# 29 121 12
# 30 158 14
# 31 158 14
# 32 158 14
# 33 158 14
# 34 158 14
# 35 158 14
# 36 158 14
# 37 158 14
# 38 158 14
# 39 158 14
# 40 158 14
# 41 158 14
# 42 161 16
# 43 161 16
# 44 161 16
# 45 161 16
# 46 176 17
# 47 176 17
# 48 176 17
# 49 176 17
# 50 176 17
# 51 176 17
# 52 176 17
# 53 176 17
# 54 176 17
# 55 176 17
# 56 176 17
# 57 176 17
# 58 176 17
# 59 176 17
# 60 183 19
# 61 183 19
# 62 183 19
# 63 183 19
# 64 183 19
# 65 183 19
# 66 183 19
# 67 183 19
# 68 183 19
# 69 183 19
# 70 183 19
# 71 189 19
# 72 189 19
# 73 189 19
# 74 224 22
# 75 224 22
# 76 224 22
# 77 224 22
# 78 224 22
# 79 224 22
# 80 224 22
# 81 224 22
# 82 224 22
# 83 224 22
# 84 224 22
# 85 224 22
# 86 224 22
# 87 224 22
# 88 224 22
# 89 224 22
# 90 224 22
# 91 224 22
# 92 224 22
# 93 224 22
# 94 224 22
# 95 224 22
# 96 224 22
# 97 224 22
# 98 224 22
# 99 224 22
# 100 224 22
# 101 224 22
# 102 224 22
# 103 224 22
# 104 224 22
# 105 224 22
# 106 224 22
# 107 224 22
# 108 224 22
# 109 224 22
# 110 224 22
# 111 224 22
# 112 224 22
# 113 224 22
# 114 224 22
# 115 224 22
# 116 224 22
# 117 228 22
# 118 228 22
# 119 228 22
# 120 228 22
# 121 228 22
# 122 228 22
# 123 228 22
# 124 228 22
# 125 228 22
# 126 228 22
# 127 228 22
# 128 228 22
# 129 228 22
# 130 228 22
# 131 228 22
# 132 228 22
# 133 228 22
# 134 228 22
# 135 228 22
# 136 228 22
# 137 228 22
# 138 228 22
# 139 228 22
# 140 228 22
# 141 228 22
# 142 228 22
# 143 228 22
# 144 228 22
# 145 228 22
# 146 228 22
# 147 228 22
# 148 228 22
# 149 228 22
# 150 228 22
# 151 228 22
# 152 230 21
# 153 230 21
# 154 230 21
# 155 230 21
# 156 230 21
# 157 230 21
# 158 230 21
# 159 230 21
# 160 232 22
# 161 232 22
# 162 232 22
# 163 232 22
# 164 232 22
# 165 232 22
# 166 243 23
# 167 243 23
# 168 243 23
# 169 243 23
# 170 243 23
# 171 243 23
# 172 243 23
# 173 243 23
# 174 243 23
# 175 243 23
# 176 243 23
# 177 243 23
# 178 243 23
# 179 243 23
# 180 243 23
# 181 243 23
# 182 243 23
# 183 243 23
# 184 243 23
# 185 243 23
# 186 243 23
# 187 243 23
# 188 243 23
# 189 243 23
# 190 243 23
# 191 248 24
# 192 248 24
# 193 248 24
# 194 248 24
# 195 248 24
# 196 248 24
# 197 248 24
# 198 248 24
# 199 248 24
# 200 248 24
# 201 248 24
# 202 248 24
# 203 248 24
# 204 248 24
# 205 248 24
# 206 248 24
# 207 248 24
# 208 249 24
# 209 249 24
# 210 249 24
# 211 249 24
# 212 249 24
# 213 249 24
# 214 249 24
# 215 249 24
# 216 249 24
# 217 249 24
# 218 249 24
# 219 249 24
# 220 249 24
# 221 249 24
# 222 249 24
# 223 249 24
# 224 249 24
# 225 249 24
# 226 249 24
# 227 249 24
# 228 249 24
# 229 249 24
# 230 249 24
# 231 249 24
# 232 249 24
# 233 249 24
# 234 249 24
# 235 249 24
# 236 249 24
# 237 249 24
# 238 249 24
# 239 249 24
# 240 249 24
# 241 249 24
# 242 249 24
# 243 249 24
# 244 249 24
# 245 249 24
# 246 249 24
# 247 249 24
# 248 249 24
# 249 249 24
# 250 249 24
# 251 249 24
# 252 249 24
# 253 249 24
# 254 249 24
# 255 249 24
# 256 249 24
# 257 249 24
# 258 249 24
# 259 249 24
# 260 249 24
# 261 249 24
# 262 249 24
# 263 249 24
# 264 249 24
# 265 249 24
# 266 249 24
# 267 249 24
# 268 249 24
# 269 249 24
# 270 249 24
# 271 249 24
# 272 249 24
# 273 249 24
# 274 249 24
# 275 249 24
# 276 249 24
# 277 249 24
# 278 249 24
# 279 249 24
# 280 249 24
# 281 249 24
# 282 249 24
# 283 249 24
# 284 249 24
# 285 249 24
# 286 249 24
# 287 249 24
# 288 249 24
# 289 249 24
# 290 249 24
# 291 249 24
# 292 249 24
# 293 249 24
# 294 249 24
# 295 249 24
# 296 249 24
# 297 249 24
# 298 249 24
# 299 249 24
# 300 249 24
# 301 249 24
# 302 249 24
# 303 252 25
# 304 252 25
# 305 252 25
# 306 252 25
# 307 252 25
# 308 252 25
# 309 252 25
# 310 252 25
# 311 252 25
# 312 252 25
# 313 252 25
# 314 252 25
# 315 252 25
# 316 252 25
# 317 252 25
# 318 252 25
# 319 252 25
# 320 252 25
# 321 252 25
# 322 252 25
# 323 252 25
# 324 252 25
# 325 252 25
# 326 252 25
# 327 252 25
# 328 252 25
# 329 252 25
# 330 252 25
# 331 252 25
# 332 252 25
# 333 252 25
# 334 252 25
# 335 252 25
# 336 252 25
# 337 252 25
# 338 252 25
# 339 252 25
# 340 252 25
# 341 252 25
# 342 252 25
# 343 252 25
# 344 252 25
# 345 252 25
# 346 252 25
# 347 252 25
# 348 252 25
# 349 252 25
# 350 252 25
# 351 252 25
# 352 252 25
# 353 252 25
# 354 252 25
# 355 252 25
# 356 252 25
# 357 252 25
# 358 252 25
# 359 252 25
# 360 252 25
# 361 252 25
# 362 252 25
# 363 252 25
# 364 252 25
# 365 252 25
# 366 252 25
# 367 252 25
# 368 252 25
# 369 252 25
# 370 252 25
# 371 252 25
# 372 252 25
# 373 252 25
# 374 252 25
# 375 252 25
# 376 252 25
# 377 252 25
# 378 252 25
# 379 252 25
# 380 252 25
# 381 252 25
# 382 252 25
# 383 252 25
# 384 252 25
# 385 252 25
# 386 252 25
# 387 252 25
# 388 252 25
# 389 252 25
# 390 252 25
# 391 252 25
# 392 252 25
# 393 252 25
# 394 252 25
# 395 252 25
# 396 252 25
# 397 252 25
# 398 252 25
# 399 252 25
# 400 252 25
# 401 252 25
# 402 252 25
# 403 252 25
# 404 252 25
# 405 252 25
# 406 252 25
# 407 252 25
# 408 252 25
# 409 252 25
# 410 252 25
# 411 252 25
# 412 252 25
# 413 252 25
# 414 252 25
# 415 252 25
# 416 252 25
# 417 252 25
# 418 252 25
# 419 252 25
# 420 252 25
# 421 252 25
# 422 252 25
# 423 252 25
# 424 252 25
# 425 252 25
# 426 252 25
# 427 252 25
# 428 252 25
# 429 252 25
# 430 252 25
# 431 252 25
# 432 252 25
# 433 252 25
# 434 252 25
# 435 252 25
# 436 252 25
# 437 252 25
# 438 252 25
# 439 252 25
# 440 252 25
# 441 252 25
# 442 252 25
# 443 252 25
# 444 252 25
# 445 252 25
# 446 252 25
# 447 252 25
# 448 252 25
# 449 252 25
# 450 252 25
# 451 252 25
# 452 252 25
# 453 252 25
# 454 252 25
# 455 252 25
# 456 252 25
# 457 252 25
# 458 252 25
# 459 252 25
# 460 252 25
# 461 252 25
# 462 252 25
# 463 252 25
# 464 252 25
# 465 252 25
# 466 252 25
# 467 252 25
# 468 252 25
# 469 252 25
# 470 252 25
# 471 252 25
# 472 252 25
# 473 252 25
# 474 252 25
# 475 252 25
# 476 252 25
# 477 252 25
# 478 252 25
# 479 252 25
# 480 252 25
# 481 252 25
# 482 252 25
# 483 252 25
# 484 252 25
# 485 252 25
# 486 252 25
# 487 252 25
# 488 252 25
# 489 252 25
# 490 252 25
# 491 252 25
# 492 252 25
# 493 252 25
# 494 252 25
# 495 252 25
# 496 252 25
# 497 252 25
# 498 252 25
# 499 252 25
# ====================
# 499 252 25
